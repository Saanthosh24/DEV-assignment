# %% [markdown]
# <a href="https://colab.research.google.com/github/Saanthosh24/DEV-assignment/blob/main/DEVassignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('International_Report_Passengers.csv',nrows=500)
df.head(500)
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1    06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3    04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 495  02/01/2003  2003      2       14027     PBI       33      13165    MAN
# 496  04/01/2004  2004      4       13342     MKE       45      14312    PVR
# 497  04/01/2009  2009      4       10721     BOS       13      16217    YUL
# 498  05/01/2010  2010      5       13303     MIA       33      12180    HOG
# 499  12/01/2005  2005     12       15016     STL       64      14312    PVR
#
# ...

# %%
x=df.Year
plt.plot(x)

# %%
y=df.Month
plt.bar(x,y)
# Out:
# <BarContainer object of 500 artists>

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([102.,  48.,  62.,  99.,  51.,  49.,  88.,   0.,   0.,   1.]),
#  array([2001. , 2002.3, 2003.6, 2004.9, 2006.2, 2007.5, 2008.8, 2010.1,
#         2011.4, 2012.7, 2014. ]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3668a03650>,
# ...
#  [Text(1.099978099703553, 0.006941193885799781, '5'),
#   Text(1.0998033589796412, 0.02079835515367853, '6'),
#   Text(1.099455033939477, 0.03462121235808453, '12'),
#   Text(1.098933590439549, 0.048424826315043676, '4'),
#   Text(1.0982388499607976, 0.0622208038905386, '12'),
#   Text(1.097369969392943, 0.07602072266514773, '3'),
#   Text(1.0963288183107418, 0.089794889283147, '3'),
#   Text(1.0951147810107902, 0.10355489564327272, '4'),
#   Text(1.0937265787737258, 0.1173122793398923, '9'),
#   Text(1.0921667879809767, 0.13104086092252568, '8'),
#   Text(1.0904333206571368, 0.14475901768335495, '6'),
#   Text(1.0885280499154424, 0.15845089001733004, '3'),
#   Text(1.0864530230626683, 0.1721041216182502, '6'),
#   Text(1.08420617082983, 0.18573362413552802, '3'),
#   Text(1.081788344047348, 0.1993338372763065, '2'),
#   Text(1.0791959215559346, 0.2129229036459845, '11'),
#   Text(1.0764292566519327, 0.22649515540904586, '11'),
# ...

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f366672e690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f3666734150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f366672e110>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3666734c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f366673d190>],
#  'means': []}
